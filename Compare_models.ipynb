# %% [markdown]
# # Compare models
#
# This compares several different models trained in turn on the *longliner*,
# *trawler* and *purse seiner* data sets.
#
# **NOTE: this was somewhat unstable. Running multiple times yielded significantly different results,
#   depending the data split.  I set seeds everywhere and now the output is stable. However, this tells
#   me that we want more data!**

# %%
# %matplotlib inline
import data
from evaluate_model import evaluate_model, train_model, compare_auc

# %%
from legacy_heuristic_model import LegacyHeuristicModel
from random_forest_model import RandomForestModel
from logistic_model import LogisticModel

untrained_models = [
    ('Logistic', LogisticModel(windows=[43200], order=6)),
    ('Logistic (MW)', LogisticModel(windows=[1800, 3600, 10800, 21600, 43200, 86400], order=6)),
    ('Logistic (MW/cross)', LogisticModel(windows=[1800, 3600, 10800, 21600, 43200, 86400], order=6, cross=2)),
    ('Random Forest', RandomForestModel(windows=[43200])),
    ('Random Forest (MW)', RandomForestModel(windows=[1800, 3600, 10800, 21600, 43200, 86400])),
    ('Legacy', LegacyHeuristicModel(window=3600)),
    ("Legacy (3 Hour)", LegacyHeuristicModel(window=10800)),
    ("Legacy (12 Hour)", LegacyHeuristicModel(window=43200)),
    ("Legacy (24 Hour)", LegacyHeuristicModel(window=86400)),  
]

# %%
for vessel_class in ["longliner", "trawl", "ps"]:
    print
    print
    print "*" * 64
    print vessel_class
    print "*" * 64
    x, xtrain, xcross, xtest = data.load_dataset_by_vessel(
            'datasets/kristina_{0}.measures.npz'.format(vessel_class))
    trained_models = [(name, train_model(mdl, xtrain)) for (name, mdl) in untrained_models]
    for name, mdl in trained_models:
        evaluate_model(mdl, xtest, name=name)
    print
    print
    print "AUC comparison for", vessel_class
    compare_auc(trained_models, xtest)
# Out:
# ****************************************************************
# longliner
# ****************************************************************
# Logistic
#
# AUC: 0.837328400425
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.56      0.77      0.65      1061
#     fishing       0.93      0.84      0.88      3939
#
# avg / total       0.85      0.82      0.83      5000
#
# False positive rate: 0.0498
# Logistic (MW)
#
# AUC: 0.874717983652
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.53      0.82      0.65      1061
#     fishing       0.94      0.80      0.87      3939
#
# avg / total       0.86      0.81      0.82      5000
#
# False positive rate: 0.0372
# Logistic (MW/cross)
#
# AUC: 0.871342162129
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.61      0.80      0.69      1061
#     fishing       0.94      0.86      0.90      3939
#
# avg / total       0.87      0.85      0.86      5000
#
# False positive rate: 0.0424
# Random Forest
#
# AUC: 0.898941181003
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.66      0.78      0.72      1061
#     fishing       0.94      0.89      0.91      3939
#
# avg / total       0.88      0.87      0.87      5000
#
# False positive rate: 0.046
# Random Forest (MW)
#
# AUC: 0.913052107792
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.64      0.81      0.72      1061
#     fishing       0.95      0.88      0.91      3939
#
# avg / total       0.88      0.86      0.87      5000
#
# False positive rate: 0.0394
# Legacy
#
# AUC: 0.563166517478
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.31      0.44      0.37      1061
#     fishing       0.83      0.74      0.78      3939
#
# avg / total       0.72      0.68      0.69      5000
#
# False positive rate: 0.1182
# Legacy (3 Hour)
#
# AUC: 0.619254062722
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.45      0.41      0.43      1061
#     fishing       0.84      0.86      0.85      3939
#
# avg / total       0.76      0.77      0.76      5000
#
# False positive rate: 0.1256
# Legacy (12 Hour)
#
# AUC: 0.694061463712
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.83      0.32      0.46      1061
#     fishing       0.84      0.98      0.91      3939
#
# avg / total       0.84      0.84      0.81      5000
#
# False positive rate: 0.1438
# Legacy (24 Hour)
#
# AUC: 0.663851228884
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.90      0.26      0.40      1061
#     fishing       0.83      0.99      0.91      3939
#
# avg / total       0.85      0.84      0.80      5000
#
# False positive rate: 0.1572
#
#
# AUC comparison for longliner
# ****************************************************************
# trawl
# ****************************************************************
# Logistic
#
# AUC: 0.90048748915
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.89      0.68      0.77      1892
#     fishing       0.83      0.95      0.89      3108
#
# avg / total       0.85      0.85      0.84      5000
#
# False positive rate: 0.1198
# Logistic (MW)
#
# AUC: 0.915705497101
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.90      0.72      0.80      1892
#     fishing       0.85      0.95      0.90      3108
#
# avg / total       0.87      0.87      0.86      5000
#
# False positive rate: 0.1044
# Logistic (MW/cross)
#
# AUC: 0.911624947962
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.89      0.73      0.80      1892
#     fishing       0.85      0.94      0.90      3108
#
# avg / total       0.87      0.86      0.86      5000
#
# False positive rate: 0.1032
# Random Forest
#
# AUC: 0.895586238609
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.78      0.76      0.77      1892
#     fishing       0.85      0.87      0.86      3108
#
# avg / total       0.83      0.83      0.83      5000
#
# False positive rate: 0.0922
# Random Forest (MW)
#
# AUC: 0.929865912424
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.89      0.77      0.83      1892
#     fishing       0.87      0.94      0.90      3108
#
# avg / total       0.88      0.88      0.87      5000
#
# False positive rate: 0.0866
# Legacy
#
# AUC: 0.738175675676
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.77      0.64      0.70      1892
#     fishing       0.80      0.88      0.84      3108
#
# avg / total       0.79      0.79      0.79      5000
#
# False positive rate: 0.1356
# Legacy (3 Hour)
#
# AUC: 0.755519752613
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.88      0.60      0.72      1892
#     fishing       0.80      0.95      0.87      3108
#
# avg / total       0.83      0.82      0.81      5000
#
# False positive rate: 0.151
# Legacy (12 Hour)
#
# AUC: 0.759403544287
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.94      0.49      0.65      1892
#     fishing       0.76      0.98      0.86      3108
#
# avg / total       0.83      0.80      0.78      5000
#
# False positive rate: 0.1912
# Legacy (24 Hour)
#
# AUC: 0.737186616547
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.94      0.42      0.58      1892
#     fishing       0.74      0.98      0.84      3108
#
# avg / total       0.81      0.77      0.74      5000
#
# False positive rate: 0.2186
#
#
# AUC comparison for trawl
# ****************************************************************
# ps
# ****************************************************************
# Logistic
#
# AUC: 0.7382617232
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.99      0.53      0.69      4814
#     fishing       0.07      0.90      0.13       186
#
# avg / total       0.96      0.55      0.67      5000
#
# False positive rate: 0.4504
# Logistic (MW)
#
# AUC: 0.889973687855
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       1.00      0.72      0.83      4814
#     fishing       0.11      0.91      0.20       186
#
# avg / total       0.96      0.72      0.81      5000
#
# False positive rate: 0.273
# Logistic (MW/cross)
#
# AUC: 0.886794117516
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.99      0.76      0.86      4814
#     fishing       0.12      0.89      0.22       186
#
# avg / total       0.96      0.76      0.84      5000
#
# False positive rate: 0.2346
# Random Forest
#
# AUC: 0.758589977262
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.98      0.72      0.83      4814
#     fishing       0.08      0.62      0.14       186
#
# avg / total       0.95      0.71      0.80      5000
#
# False positive rate: 0.2734
# Random Forest (MW)
#
# AUC: 0.904228147294
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.99      0.83      0.90      4814
#     fishing       0.16      0.83      0.26       186
#
# avg / total       0.96      0.83      0.88      5000
#
# False positive rate: 0.1662
# Legacy
#
# AUC: 0.668100097833
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       1.00      0.40      0.57      4814
#     fishing       0.06      0.99      0.11       186
#
# avg / total       0.96      0.42      0.56      5000
#
# False positive rate: 0.575
# Legacy (3 Hour)
#
# AUC: 0.661697401396
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       1.00      0.37      0.54      4814
#     fishing       0.06      0.98      0.11       186
#
# avg / total       0.96      0.39      0.53      5000
#
# False positive rate: 0.6046
# Legacy (12 Hour)
#
# AUC: 0.559820483268
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       1.00      0.26      0.42      4814
#     fishing       0.05      0.97      0.09       186
#
# avg / total       0.96      0.29      0.40      5000
#
# False positive rate: 0.7098
# Legacy (24 Hour)
#
# AUC: 0.502618929556
# For cutoff of 0.5:
#              precision    recall  f1-score   support
#
# non-fishing       0.99      0.20      0.33      4814
#     fishing       0.04      0.96      0.08       186
#
# avg / total       0.96      0.23      0.32      5000
#
# False positive rate: 0.7704
#
#
# AUC comparison for ps
