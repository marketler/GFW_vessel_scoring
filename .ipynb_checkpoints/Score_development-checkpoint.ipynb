# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv
from scipy.optimize import *
from numpy.lib.recfunctions import *
from utils import *
from data import *

# %%
# Print data columns
x.dtype.names
# Out:
# ('classification',
#  'distance_to_port',
#  'distance_to_shore',
#  'measure_course_diff',
#  'measure_courseavg_10800',
#  'measure_courseavg_1800',
#  'measure_courseavg_21600',
#  'measure_courseavg_3600',
#  'measure_courseavg_43200',
#  'measure_courseavg_86400',
#  'measure_coursestddev_10800',
#  'measure_coursestddev_1800',
#  'measure_coursestddev_21600',
#  'measure_coursestddev_3600',
#  'measure_coursestddev_43200',
#  'measure_coursestddev_86400',
#  'measure_distance_to_port',
#  'measure_heading_diff',
#  'measure_new_score_10800',
#  'measure_new_score_1800',
#  'measure_new_score_21600',
#  'measure_new_score_3600',
#  'measure_new_score_43200',
#  'measure_new_score_86400',
#  'measure_pos_10800',
#  'measure_pos_1800',
#  'measure_pos_21600',
#  'measure_pos_3600',
#  'measure_pos_43200',
#  'measure_pos_86400',
#  'measure_speed',
#  'measure_speed_diff',
#  'measure_speedavg_10800',
#  'measure_speedavg_1800',
#  'measure_speedavg_21600',
# ...

# %%
windows = [int(name[len("measure_courseavg_"):]) for name in x.dtype.names if name.startswith("measure_courseavg_")]
windows.sort()
print windows
# Out:
# [1800, 3600, 10800, 21600, 43200, 86400]

# %%
def graph_expr(field = None, expr = None, label = None, bins=200, ylim=None):
    if field and not label:
        label = field
    def fn(arr):
        if field:
            arr = arr[field]
        if expr:
            arr = expr(arr)
        return arr

    histfix = figure(figsize=(20,5))
    
    if ylim is not None:
        histfix.add_subplot(111).set_ylim(*ylim)

    xfishy_hist = center_hist_bins(hist(fn(xfishy), bins=bins, normed=True, color='b', alpha=0.5, label="fishy %s" % label))
    xnonfishy_hist = center_hist_bins(hist(fn(xnonfishy), bins=bins, normed=True, color='r', alpha=0.5, label="nonfishy %s" % label))

    x_hist = (xfishy_hist[0] - xnonfishy_hist[0], xfishy_hist[1])

    args = curve_fit(polynomial, x_hist[1], x_hist[0], [1]*6)[0]

    plot(x_hist[1], x_hist[0], color='b', label='%s fishy-nonfishy' % label)
    plot(x_hist[1], [polynomial(value, *args) for value in x_hist[1]], color='r', label='fishy %s score' % label)

    legend()
    show()
    
    return args

speed_args = graph_expr("speed", lambda arr: clamp(arr/17, 0, 1), bins=50)
    
args = {}
for window in windows:
    args[window] = {}
for window in windows:
    args[window]["measure_speedavg"] = graph_expr("measure_speedavg_%s" % window, ylim=(-5, 5))
for window in windows:
    args[window]["measure_speedstddev"] = graph_expr("measure_speedstddev_%s" % window, lambda arr: log10(arr+0.001), ylim=(-3, 3))
for window in windows:
    args[window]["measure_coursestddev"] = graph_expr("measure_coursestddev_%s" % window, lambda arr: log10(arr+0.001), ylim=(-1.5, 1.5))

# %%
try:
    x = append_fields(x, 'score_speed', [], dtypes='<f8', fill_value=0.0)
    for window in windows:
        x = append_fields(x, 'score_speedavg_%s' % window, [], dtypes='<f8', fill_value=0.0)
        x = append_fields(x, 'score_speedstddev_%s' % window, [], dtypes='<f8', fill_value=0.0)
        x = append_fields(x, 'score_coursestddev_%s' % window, [], dtypes='<f8', fill_value=0.0)
except:
    pass

x['score_speed'][:] = polynomial(clamp(x["speed"]/17, 0, 1), *speed_args)
for window in windows:
    x['score_speedavg_%s' % window][:] = polynomial(x['measure_speedavg_%s' % window], *args[window]["measure_speedavg"])
    x['score_speedstddev_%s' % window][:] = polynomial(log10(x['measure_speedstddev_%s' % window]+0.001), *args[window]["measure_speedstddev"])
    x['score_coursestddev_%s' % window][:] = polynomial(log10(x['measure_coursestddev_%s' % window]+0.001), *args[window]["measure_coursestddev"])

xfishy = fishy(x)
xnonfishy = nonfishy(x)

# %%
try:
    for window in windows:
        x = append_fields(x, 'score_%s' % window, [], dtypes='<f8', fill_value=0.0)
except:
    pass


score_args = {}
for window in windows:
    cols = ['score_speed',
            'score_speedavg_%s' % window,
            'score_speedstddev_%s' % window,
            'score_coursestddev_%s' % window]
    
    cols = [x[col] for col in cols]
    
    score_args[window] = curve_fit(linear, cols, x['classification'], [1]*len(cols))[0]

    x['score_%s' % window][:] = linear(cols, *score_args[window])

    xfishy = fishy(x)
    xnonfishy = nonfishy(x)

    histfig = figure(figsize=(20,5))

    subplot = histfig.add_subplot(211)
    new_score_fishy = subplot.hist(xfishy["measure_new_score_%s" % window][xfishy['distance_to_shore'] > 3], bins=200, normed=False, color='b', alpha=0.5, label="fishy score %s" % window)
    new_score_nonfishy = subplot.hist(xnonfishy["measure_new_score_%s" % window][xnonfishy['distance_to_shore'] > 3], bins=200, normed=False, color='r', alpha=0.5, label="nonfishy score %s" % window)
    legend()

    subplot = histfig.add_subplot(212)
    score_fishy = subplot.hist(xfishy["score_%s" % window][xfishy['distance_to_shore'] > 3], bins=200, normed=False, color='b', alpha=0.5, label="fishy new score %s" % window)
    score_nonfishy = subplot.hist(xnonfishy["score_%s" % window][xnonfishy['distance_to_shore'] > 3], bins=200, normed=False, color='r', alpha=0.5, label="nonfishy new score %s" % window)
    legend()

    show()
    
    print "Window: %s" % window
    total = sum(new_score_fishy[0] + new_score_nonfishy[0])
    non_overlap = sum(abs(new_score_fishy[0] - new_score_nonfishy[0]))
    overlap = total - non_overlap
    error = overlap / total

    print "    Error for score: %s%%" % (error * 100)

    total = sum(score_fishy[0] + score_nonfishy[0])
    non_overlap = sum(abs(score_fishy[0] - score_nonfishy[0]))
    overlap = total - non_overlap
    error = overlap / total

    print "    Error for new score: %s%%" % (error * 100)
# Out:
# Window: 1800
#     Error for score: 43.414511467%
#     Error for new score: 45.8894741738%
# Window: 3600
#     Error for score: 42.1728959889%
#     Error for new score: 41.1035357102%
# Window: 10800
#     Error for score: 27.9866467769%
#     Error for new score: 36.1012447161%
# Window: 21600
#     Error for score: 22.5282240144%
#     Error for new score: 27.5704782149%
# Window: 43200
#     Error for score: 20.4101740811%
#     Error for new score: 23.4439326551%
# Window: 86400
#     Error for score: 23.6547730193%
#     Error for new score: 26.5011179362%

# %%
cols = ["score_speed"]
for window in windows:
    cols += ['score_speedavg_%s' % window,
             'score_speedstddev_%s' % window,
             'score_coursestddev_%s' % window]
cols = [x[col] for col in cols]
    
score_args = curve_fit(linear, cols, x['classification'], [1]*len(cols))[0]

try:
    x = append_fields(x, 'score', [], dtypes='<f8', fill_value=0.0)
except:
    pass

x['score'][:] = linear(cols, *score_args)

xfishy = fishy(x)
xnonfishy = nonfishy(x)


histfig = figure(figsize=(20,5))

subplot = histfig.add_subplot(211)
new_score_fishy = subplot.hist(xfishy["measure_new_score_3600"][xfishy['distance_to_shore'] > 3], bins=200, normed=False, color='b', alpha=0.5, label="fishy score")
new_score_nonfishy = subplot.hist(xnonfishy["measure_new_score_3600"][xnonfishy['distance_to_shore'] > 3], bins=200, normed=False, color='r', alpha=0.5, label="nonfishy score")
legend()

subplot = histfig.add_subplot(212)
score_fishy = subplot.hist(xfishy["score"][xfishy['distance_to_shore'] > 3], bins=200, normed=False, color='b', alpha=0.5, label="fishy score")
score_nonfishy = subplot.hist(xnonfishy["score"][xnonfishy['distance_to_shore'] > 3], bins=200, normed=False, color='r', alpha=0.5, label="nonfishy score")
legend()


show()

total = sum(new_score_fishy[0] + new_score_nonfishy[0])
non_overlap = sum(abs(new_score_fishy[0] - new_score_nonfishy[0]))
overlap = total - non_overlap
error = overlap / total

print "Error for measure_new_score: %s%%" % (error * 100)


total = sum(score_fishy[0] + score_nonfishy[0])
non_overlap = sum(abs(score_fishy[0] - score_nonfishy[0]))
overlap = total - non_overlap
error = overlap / total

print "Error for score: %s%%" % (error * 100)
# Out:
# Error for measure_new_score: 42.1728959889%
# Error for score: 24.7999255858%
